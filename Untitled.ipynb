# %% [markdown]
# Initial state of notebook

# %% [markdown]
# Adding first cell

# %%
a = 1
b = 3

a+b -1
# Out:
# 3

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x = np.linspace(0,1000,1001)
y = x**2

# %%
plt.plot(x,y)
